# %%
import numpy as np

import cv2

import matplotlib.pyplot as plt

# %%
img = cv2.imread("media/trump_biden.png")

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)

# %%
red = img_rgb[..., 0]

green = img_rgb[..., 1]

blue = img_rgb[..., 2]

# %%
red
# Out:
# array([[207, 208, 210, ..., 216, 219, 221],
#        [204, 205, 207, ..., 216, 218, 220],
#        [200, 201, 204, ..., 214, 216, 218],
#        ...,
#        [180,  78,  16, ..., 172, 170, 168],
#        [150,  47,  14, ..., 168, 165, 164],
#        [119,  28,  19, ..., 166, 163, 161]], dtype=uint8)

# %%
yellow = np.zeros((img_rgb.shape[0], img_rgb.shape[1]), dtype = "uint16")

# %%
yellow= red + green

# %%
yellow
# Out:
# array([[149, 151, 155, ..., 170, 176, 180],
#        [143, 145, 149, ..., 170, 174, 178],
#        [135, 137, 143, ..., 166, 170, 174],
#        ...,
#        [ 85, 138,  19, ...,  62,  58,  54],
#        [ 25,  77,  16, ...,  54,  48,  46],
#        [219,  39,  25, ...,  50,  44,  40]], dtype=uint8)

# %%
plt.imshow(yellow, cmap = "gray")

# %%
plt.imshow(yellow[..., 1], cmap = "gray")

# %%
plt.imshow(yellow[..., 2], cmap = "gray")

# %%
yellow
# Out:
# array([[149, 151, 155, ..., 170, 176, 180],
#        [143, 145, 149, ..., 170, 174, 178],
#        [135, 137, 143, ..., 166, 170, 174],
#        ...,
#        [ 85, 138,  19, ...,  62,  58,  54],
#        [ 25,  77,  16, ...,  54,  48,  46],
#        [219,  39,  25, ...,  50,  44,  40]], dtype=uint8)

# %%
ciano = np.zeros((img_rgb.shape[0], img_rgb.shape[1]), dtype = "uint16")

# %%
ciano = green + blue

# %%
ciano
# Out:
# array([[109, 111, 115, ..., 140, 146, 150],
#        [103, 105, 109, ..., 140, 144, 148],
#        [ 95,  97, 103, ..., 136, 140, 144],
#        ...,
#        [ 48, 107,   3, ..., 233, 229, 225],
#        [247,  49,   2, ..., 225, 219, 217],
#        [186,  12,  10, ..., 221, 215, 211]], dtype=uint8)

# %%
magenta = np.zeros((img_rgb.shape[0], img_rgb.shape[1]), dtype = "uint16")

# %%
magenta = red + blue

# %%
magenta
# Out:
# array([[118, 120, 124, ..., 146, 152, 156],
#        [112, 114, 118, ..., 146, 150, 154],
#        [104, 106, 112, ..., 142, 146, 150],
#        ...,
#        [ 67, 125,  16, ...,   3, 255, 251],
#        [ 10,  66,  14, ..., 251, 245, 243],
#        [205,  29,  23, ..., 247, 241, 237]], dtype=uint8)

# %%
def plot_channels(color):
    for i in range(3):
        plt.imshow(color[..., i], cmap = "gray")
        plt.show()

# %%
array = np.zeros((img.shape[0], img.shape[1], 3), dtype = "uint8")

# %%
array[..., 0] = ciano

array[..., 1] = magenta

array[..., 2] = yellow

# %%
plt.imshow(array)
