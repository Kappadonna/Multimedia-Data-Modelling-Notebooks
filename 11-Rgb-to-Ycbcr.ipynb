# %%
import numpy as np

import matplotlib.pyplot as plt

import cv2

# %%
img = cv2.imread("media/trump_biden.png")

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %%
img.shape
# Out:
# (752, 1440, 3)

# %%
matrix = np.array([[0.299, 0.587, 0.114], [0.596, -0.275, -0.321], [0.212, -0.523, 0.311]])

# %%
matrix
# Out:
# array([[ 0.299,  0.587,  0.114],
#        [ 0.596, -0.275, -0.321],
#        [ 0.212, -0.523,  0.311]])

# %%
matrix.shape
# Out:
# (3, 3)

# %%
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        img[i, j, :] = img[i, j, :]@M

# %%
ciao
# Out:
# np.float64(219906.62299999996)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 np.sum(matrix[0] * img[..., 0])
#
# ValueError: operands could not be broadcast together with shapes (3,) (752,1440)
