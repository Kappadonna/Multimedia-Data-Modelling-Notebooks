# %%
import numpy as np

import cv2

import matplotlib.pyplot as plt

# %%
img = cv2.imread("Media/Trump.jpeg")

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %%
def histIMg(img):
    h = np.zeros((256), dtype = "int32")
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            h[img[i, j]] +=1
