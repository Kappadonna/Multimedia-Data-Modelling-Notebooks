# %%
import cv2

import matplotlib.pyplot as plt

import numpy as np

# %%
img = cv2.imread('media/inter.png')

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
# Out:
# libpng warning: iCCP: too many profiles

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(img_gray, cmap= 'gray')

# %%
img_gray
# Out:
# array([[209, 198, 195, ..., 254, 254, 255],
#        [205, 238, 212, ..., 254, 254, 254],
#        [231, 255, 230, ..., 254, 252, 253],
#        ...,
#        [  2,   1,   0, ...,  60,  61,  61],
#        [  2,   0,   0, ...,  60,  60,  60],
#        [  2,   0,   0, ...,  62,  61,  60]], dtype=uint8)

# %%
h = img_gray.shape[0]

w = img_gray.shape[1]

# %%
img_bin = np.empty((h, w), dtype = 'object')

for i in range(img_gray.shape[0]):
    for j in range(img_gray.shape[1]):
        img_bin[i, j] = format(img_gray[i, j], '08b')
        

img_bin
# Out:
# array([['11010001', '11000110', '11000011', ..., '11111110', '11111110',
#         '11111111'],
#        ['11001101', '11101110', '11010100', ..., '11111110', '11111110',
#         '11111110'],
#        ['11100111', '11111111', '11100110', ..., '11111110', '11111100',
#         '11111101'],
#        ...,
#        ['00000010', '00000001', '00000000', ..., '00111100', '00111101',
#         '00111101'],
#        ['00000010', '00000000', '00000000', ..., '00111100', '00111100',
#         '00111100'],
#        ['00000010', '00000000', '00000000', ..., '00111110', '00111101',
#         '00111100']], dtype=object)

# %%
def bit_plane(img, n):
